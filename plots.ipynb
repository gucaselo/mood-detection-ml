# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Facial Detection

# %%
face_df = pd.read_csv("facial_detection/emotions_features_final.csv")
face_df
# Out:
#        Unnamed: 0  emotion_code   emotion  data0  data1  data2  data3  data4  \
# 0               0             0     angry     68     77     64     96     62
# 1               1             0     angry     12     89     23    109     34
# 2               2             0     angry     18     76     22     98     29
# 3               3             0     angry     30     77     33     98     39
# 4               4             0     angry     22    111     27    129     32
# ...           ...           ...       ...    ...    ...    ...    ...    ...
# 21131       21131             5  surprise     34     81     35    100     38
# 21132       21132             5  surprise     39     76     36     93     36
# 21133       21133             5  surprise     18     85     19    107     21
# 21134       21134             5  surprise     29     89     28    109     29
# 21135       21135             5  surprise     -2     62     -2     87     -1
#
# ...

# %%
face_plot = face_df.groupby(by='emotion').count()
face_plot.rename(columns={"Unnamed: 0" : "Count"}, inplace=True)
face_plot
# Out:
#           Count  emotion_code  data0  data1  data2  data3  data4  data5  \
# emotion
# angry      2912          2912   2912   2912   2912   2912   2912   2912
# disgust     352           352    352    352    352    352    352    352
# fear       2711          2711   2711   2711   2711   2711   2711   2711
# happy      5908          5908   5908   5908   5908   5908   5908   5908
# neutral    3890          3890   3890   3890   3890   3890   3890   3890
# sad        2911          2911   2911   2911   2911   2911   2911   2911
# surprise   2452          2452   2452   2452   2452   2452   2452   2452
#
#           data6  data7  ...  data126  data127  data128  data129  data130  \
# emotion                 ...
# angry      2912   2912  ...     2912     2912     2912     2912     2912
# disgust     352    352  ...      352      352      352      352      352
# fear       2711   2711  ...     2711     2711     2711     2711     2711
# ...

# %%
face_bar = face_plot['Count']
face_bar.plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='emotion'>

# %% [markdown]
# ## Voice

# %%
voice_df = pd.read_csv("voice_detection/data/mood_features.csv")
voice_df.drop(['code'], axis =1, inplace = True)
voice_df
# Out:
#        emotions                                           features
# 0       neutral  [-6.93497009e+02  5.00643921e+01  5.71450591e-...
# 1       neutral  [-6.83346802e+02  4.88892593e+01 -1.68344426e+...
# 2       neutral  [-6.77770935e+02  5.14486465e+01  2.55120564e-...
# 3       neutral  [-6.73948181e+02  5.07293015e+01  1.86326182e+...
# 4          calm  [-7.09033447e+02  5.57661018e+01  2.69817996e+...
# ...         ...                                                ...
# 1435  surprised  [-5.72820374e+02  1.74811192e+01 -1.67859116e+...
# 1436  surprised  [-5.19959106e+02  3.12915001e+01 -1.75921307e+...
# 1437  surprised  [-5.32108765e+02  2.32904148e+01 -1.99681702e+...
# 1438  surprised  [-4.87082245e+02  2.08570232e+01 -5.49205065e+...
# 1439  surprised  [-5.08829681e+02  2.75565186e+01 -5.73707199e+...
#
# [1440 rows x 2 columns]

# %%
sample = voice_df.head(50)
sample.head(1)
sample['features']= sample['features'].astype(str).str[1:-1]

# %%
voice_scatter = sample.plot.scatter(x='emotions',y='features', c='DarkBlue')
y_axis = voice_scatter.axes.get_yaxis()
y_axis.set_visible(False)

# %% [markdown]
# ## Text

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from pandas import DataFrame
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
import numpy as np

import nltk
# if it is the first time using nltk uncomment line below and run it and download it
# nltk.download()
from nltk import word_tokenize
from nltk.corpus import stopwords
import string
# Out:
# ...
# zsh:1: command not found: setup.py
# ...

# %%
df = pd.read_csv('text_detection/sentiment-analysis-dataset.csv', error_bad_lines=False)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-a330a6342494> in <module>
# ----> 1 from google.colab import files
#       2 uploaded = files.upload()
#       3 text_df = pd.read_csv(io.StringIO(uploaded['sentiment-analysis-dataset.csv'].decode('utf-8')))
#       4 text_df
#
# ModuleNotFoundError: No module named 'google.colab'
